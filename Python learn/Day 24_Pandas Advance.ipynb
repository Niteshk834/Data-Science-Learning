# %%
import pandas as pd

# %%
df=pd.read_csv("plazaPassList2.csv")

# %%
df.head(3)
# Out:
#    Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 0        1  34161FA82033E6EE04FFF900          MP10CB0412                VC4
# 1        2  34161FA82033E6EE04FFF900          MP10CB0412                VC4
# 2        3  34161FA82033E6EE0488C6C0          UP32EF9515                VC4
#
#   Vehicle Class Desc         Plaza Name   Pass Id            Pass Scheme  \
# 0   Car / Jeep / Van  Kurana Toll Plaza  14540747  Monthly Pass Non Comm
# 1   Car / Jeep / Van  Kurana Toll Plaza  14104436  Monthly Pass Non Comm
# 2   Car / Jeep / Van  Kurana Toll Plaza  14226402  Monthly Pass Non Comm
#
#   Pass Type              Pass Name  ... Stlmnt Amt (Rs.) Stlmnt Status  \
# 0        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 1        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 2        MP  Monthly Pass Non Comm  ...              NaN           NaN
#
#    Current Status    Issued By NPCI Plaza Id AutoRenewal  Old Pass Id  \
# ...

# %%
df.columns
# Out:
# Index(['Sr. No.', 'Tag ID', 'Chassis/ Vehicle No', 'NPCI Vehicle Class',
#        'Vehicle Class Desc', 'Plaza Name', 'Pass Id', 'Pass Scheme',
#        'Pass Type', 'Pass Name', 'Start Effective Date', 'End Effective Date',
#        'Trips Allowed', 'Trips Taken', 'Channel', 'Issuance Date',
#        'Renewal Dt', 'Issuance Fees (Rs.)', 'Payment Mode', 'Payment status',
#        'Stlmnt Dt', 'Stlmnt Amt (Rs.)', 'Stlmnt Status', 'Current Status',
#        'Issued By', 'NPCI Plaza Id', 'AutoRenewal', 'Old Pass Id',
#        'New Pass Id', 'A', 'B'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Sr. No.                   int64
# Tag ID                   object
# Chassis/ Vehicle No      object
# NPCI Vehicle Class       object
# Vehicle Class Desc       object
# Plaza Name               object
# Pass Id                   int64
# Pass Scheme              object
# Pass Type                object
# Pass Name                object
# Start Effective Date     object
# End Effective Date       object
# Trips Allowed             int64
# Trips Taken               int64
# Channel                  object
# Issuance Date            object
# Renewal Dt              float64
# Issuance Fees (Rs.)       int64
# Payment Mode            float64
# Payment status           object
# Stlmnt Dt                object
# Stlmnt Amt (Rs.)        float64
# Stlmnt Status            object
# Current Status           object
# Issued By                object
# NPCI Plaza Id             int64
# AutoRenewal              object
# Old Pass Id             float64
# New Pass Id             float64
# ...

# %%
df.describe() # it will give summarized report of dtypes int and float.
# Out:
#            Sr. No.       Pass Id  Trips Allowed  Trips Taken  Renewal Dt  \
# count  1012.000000  1.012000e+03    1012.000000  1012.000000         0.0
# mean    506.500000  1.415864e+07    9772.886364    19.414032         NaN
# std     292.283538  1.986372e+05    1483.459386    16.548568         NaN
# min       1.000000  1.396136e+07      50.000000     0.000000         NaN
# 25%     253.750000  1.400765e+07    9999.000000     7.000000         NaN
# 50%     506.500000  1.408078e+07    9999.000000    14.000000         NaN
# 75%     759.250000  1.422481e+07    9999.000000    30.000000         NaN
# max    1012.000000  1.462149e+07    9999.000000   105.000000         NaN
#
#        Issuance Fees (Rs.)  Payment Mode  Stlmnt Amt (Rs.)  NPCI Plaza Id  \
# count          1012.000000           0.0              97.0         1012.0
# mean            429.041502           NaN             315.0       320077.0
# std             841.516647           NaN               0.0            0.0
# ...

# %%
# Selection of only object data types

# %%
df1=df.select_dtypes(include=['object'])

# %%
list(df1.columns) # only object data types column will show
# Out:
# ['Tag ID',
#  'Chassis/ Vehicle No',
#  'NPCI Vehicle Class',
#  'Vehicle Class Desc',
#  'Plaza Name',
#  'Pass Scheme',
#  'Pass Type',
#  'Pass Name',
#  'Start Effective Date',
#  'End Effective Date',
#  'Channel',
#  'Issuance Date',
#  'Payment status',
#  'Stlmnt Dt',
#  'Stlmnt Status',
#  'Current Status',
#  'Issued By',
#  'AutoRenewal']

# %%
df1.describe() # describe object dtypes
# Out:
#                           Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# count                       1012                1012               1012
# unique                       945                 944                  5
# top     34161FA8203289DA0B7D5660          UP81CD0470                VC4
# freq                           3                   3                999
#
#        Vehicle Class Desc         Plaza Name            Pass Scheme Pass Type  \
# count                1012               1012                   1012      1012
# unique                  5                  1                      2         1
# top      Car / Jeep / Van  Kurana Toll Plaza  Monthly Pass Non Comm        MP
# freq                  999               1012                    989      1012
#
#                     Pass Name Start Effective Date   End Effective Date  \
# count                    1012                 1012                 1012
# ...

# %%
# Another way

# %%
df.select_dtypes(include=['object']).describe()
# Out:
#                           Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# count                       1012                1012               1012
# unique                       945                 944                  5
# top     34161FA8203289DA0B7D5660          UP81CD0470                VC4
# freq                           3                   3                999
#
#        Vehicle Class Desc         Plaza Name            Pass Scheme Pass Type  \
# count                1012               1012                   1012      1012
# unique                  5                  1                      2         1
# top      Car / Jeep / Van  Kurana Toll Plaza  Monthly Pass Non Comm        MP
# freq                  999               1012                    989      1012
#
#                     Pass Name Start Effective Date   End Effective Date  \
# count                    1012                 1012                 1012
# ...

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Tag ID', 'Chassis/ Vehicle No', 'NPCI Vehicle Class',
#        'Vehicle Class Desc', 'Plaza Name', 'Pass Scheme', 'Pass Type',
#        'Pass Name', 'Start Effective Date', 'End Effective Date', 'Channel',
#        'Issuance Date', 'Payment status', 'Stlmnt Dt', 'Stlmnt Status',
#        'Current Status', 'Issued By', 'AutoRenewal'],
#       dtype='object')

# %%
df.select_dtypes(include=["int64"]).describe()
# Out:
#            Sr. No.       Pass Id  Trips Allowed  Trips Taken  \
# count  1012.000000  1.012000e+03    1012.000000  1012.000000
# mean    506.500000  1.415864e+07    9772.886364    19.414032
# std     292.283538  1.986372e+05    1483.459386    16.548568
# min       1.000000  1.396136e+07      50.000000     0.000000
# 25%     253.750000  1.400765e+07    9999.000000     7.000000
# 50%     506.500000  1.408078e+07    9999.000000    14.000000
# 75%     759.250000  1.422481e+07    9999.000000    30.000000
# max    1012.000000  1.462149e+07    9999.000000   105.000000
#
#        Issuance Fees (Rs.)  NPCI Plaza Id
# count          1012.000000         1012.0
# mean            429.041502       320077.0
# std             841.516647            0.0
# min             315.000000       320077.0
# 25%             315.000000       320077.0
# 50%             315.000000       320077.0
# 75%             315.000000       320077.0
# max           11435.000000       320077.0

# %%
df.select_dtypes(include=["float64"]).describe()
# Out:
#        Renewal Dt  Payment Mode  Stlmnt Amt (Rs.)  Old Pass Id  New Pass Id  \
# count         0.0           0.0              97.0          0.0          0.0
# mean          NaN           NaN             315.0          NaN          NaN
# std           NaN           NaN               0.0          NaN          NaN
# min           NaN           NaN             315.0          NaN          NaN
# 25%           NaN           NaN             315.0          NaN          NaN
# 50%           NaN           NaN             315.0          NaN          NaN
# 75%           NaN           NaN             315.0          NaN          NaN
# max           NaN           NaN             315.0          NaN          NaN
#
#          A    B
# count  0.0  0.0
# mean   NaN  NaN
# std    NaN  NaN
# min    NaN  NaN
# 25%    NaN  NaN
# 50%    NaN  NaN
# 75%    NaN  NaN
# max    NaN  NaN

# %%
df.select_dtypes(include=["float64","int64"])[0:4]
# Out:
#    Sr. No.   Pass Id  Trips Allowed  Trips Taken  Renewal Dt  \
# 0        1  14540747           9999           29         NaN
# 1        2  14104436           9999           36         NaN
# 2        3  14226402           9999            3         NaN
# 3        4  14042146           9999           15         NaN
#
#    Issuance Fees (Rs.)  Payment Mode  Stlmnt Amt (Rs.)  NPCI Plaza Id  \
# 0                  315           NaN               NaN         320077
# 1                  315           NaN               NaN         320077
# 2                  315           NaN               NaN         320077
# 3                  315           NaN               NaN         320077
#
#    Old Pass Id  New Pass Id   A   B
# 0          NaN          NaN NaN NaN
# 1          NaN          NaN NaN NaN
# 2          NaN          NaN NaN NaN
# 3          NaN          NaN NaN NaN

# %%
df.describe()
# Out:
#            Sr. No.       Pass Id  Trips Allowed  Trips Taken  Renewal Dt  \
# count  1012.000000  1.012000e+03    1012.000000  1012.000000         0.0
# mean    506.500000  1.415864e+07    9772.886364    19.414032         NaN
# std     292.283538  1.986372e+05    1483.459386    16.548568         NaN
# min       1.000000  1.396136e+07      50.000000     0.000000         NaN
# 25%     253.750000  1.400765e+07    9999.000000     7.000000         NaN
# 50%     506.500000  1.408078e+07    9999.000000    14.000000         NaN
# 75%     759.250000  1.422481e+07    9999.000000    30.000000         NaN
# max    1012.000000  1.462149e+07    9999.000000   105.000000         NaN
#
#        Issuance Fees (Rs.)  Payment Mode  Stlmnt Amt (Rs.)  NPCI Plaza Id  \
# count          1012.000000           0.0              97.0         1012.0
# mean            429.041502           NaN             315.0       320077.0
# std             841.516647           NaN               0.0            0.0
# ...

# %%
df.dtypes.describe()
# Out:
# count         31
# unique         3
# top       object
# freq          18
# dtype: object

# %%
df.select_dtypes(include=["float64","int64","object"]).describe() # still object excluded here
# Out:
#            Sr. No.       Pass Id  Trips Allowed  Trips Taken  Renewal Dt  \
# count  1012.000000  1.012000e+03    1012.000000  1012.000000         0.0
# mean    506.500000  1.415864e+07    9772.886364    19.414032         NaN
# std     292.283538  1.986372e+05    1483.459386    16.548568         NaN
# min       1.000000  1.396136e+07      50.000000     0.000000         NaN
# 25%     253.750000  1.400765e+07    9999.000000     7.000000         NaN
# 50%     506.500000  1.408078e+07    9999.000000    14.000000         NaN
# 75%     759.250000  1.422481e+07    9999.000000    30.000000         NaN
# max    1012.000000  1.462149e+07    9999.000000   105.000000         NaN
#
#        Issuance Fees (Rs.)  Payment Mode  Stlmnt Amt (Rs.)  NPCI Plaza Id  \
# count          1012.000000           0.0              97.0         1012.0
# mean            429.041502           NaN             315.0       320077.0
# std             841.516647           NaN               0.0            0.0
# ...

# %%
df.head(2)
# Out:
#    Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 0        1  34161FA82033E6EE04FFF900          MP10CB0412                VC4
# 1        2  34161FA82033E6EE04FFF900          MP10CB0412                VC4
#
#   Vehicle Class Desc         Plaza Name   Pass Id            Pass Scheme  \
# 0   Car / Jeep / Van  Kurana Toll Plaza  14540747  Monthly Pass Non Comm
# 1   Car / Jeep / Van  Kurana Toll Plaza  14104436  Monthly Pass Non Comm
#
#   Pass Type              Pass Name  ... Stlmnt Amt (Rs.) Stlmnt Status  \
# 0        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 1        MP  Monthly Pass Non Comm  ...              NaN           NaN
#
#    Current Status    Issued By NPCI Plaza Id AutoRenewal  Old Pass Id  \
# 0         EXPIRED  139773.KUR2        320077          NO          NaN
# 1         EXPIRED  139773.KUR2        320077          NO          NaN
#
#    New Pass Id   A   B
# 0          NaN NaN NaN
# 1          NaN NaN NaN
#
# ...

# %%
# Add new column

# %%
df["ne_column"]=15

# %%
df.head(3)
# Out:
#    Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 0        1  34161FA82033E6EE04FFF900          MP10CB0412                VC4
# 1        2  34161FA82033E6EE04FFF900          MP10CB0412                VC4
# 2        3  34161FA82033E6EE0488C6C0          UP32EF9515                VC4
#
#   Vehicle Class Desc         Plaza Name   Pass Id            Pass Scheme  \
# 0   Car / Jeep / Van  Kurana Toll Plaza  14540747  Monthly Pass Non Comm
# 1   Car / Jeep / Van  Kurana Toll Plaza  14104436  Monthly Pass Non Comm
# 2   Car / Jeep / Van  Kurana Toll Plaza  14226402  Monthly Pass Non Comm
#
#   Pass Type              Pass Name  ... Stlmnt Amt (Rs.) Stlmnt Status  \
# 0        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 1        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 2        MP  Monthly Pass Non Comm  ...              NaN           NaN
#
#    Current Status    Issued By NPCI Plaza Id AutoRenewal  Old Pass Id  \
# ...

# %%
# Add new column and data should be the summation of two column

# %%
df["new_col1"]=df["Chassis/ Vehicle No"]+df["Vehicle Class Desc"]

# %%
df.head(2)
# Out:
#    Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 0        1  34161FA82033E6EE04FFF900          MP10CB0412                VC4
# 1        2  34161FA82033E6EE04FFF900          MP10CB0412                VC4
#
#   Vehicle Class Desc         Plaza Name   Pass Id            Pass Scheme  \
# 0   Car / Jeep / Van  Kurana Toll Plaza  14540747  Monthly Pass Non Comm
# 1   Car / Jeep / Van  Kurana Toll Plaza  14104436  Monthly Pass Non Comm
#
#   Pass Type              Pass Name  ... Current Status    Issued By  \
# 0        MP  Monthly Pass Non Comm  ...        EXPIRED  139773.KUR2
# 1        MP  Monthly Pass Non Comm  ...        EXPIRED  139773.KUR2
#
#    NPCI Plaza Id  AutoRenewal Old Pass Id New Pass Id   A   B  ne_column  \
# 0         320077           NO         NaN         NaN NaN NaN         15
# 1         320077           NO         NaN         NaN NaN NaN         15
#
#                      new_col1
# 0  MP10CB0412Car / Jeep / Van
# ...

# %%
df["Vehicle Class Desc"]
# Out:
# 0       Car / Jeep / Van
# 1       Car / Jeep / Van
# 2       Car / Jeep / Van
# 3       Car / Jeep / Van
# 4       Car / Jeep / Van
#               ...
# 1007    Car / Jeep / Van
# 1008    Car / Jeep / Van
# 1009    Car / Jeep / Van
# 1010    Car / Jeep / Van
# 1011    Car / Jeep / Van
# Name: Vehicle Class Desc, Length: 1012, dtype: object

# %%
pd.Categorical(df["Vehicle Class Desc"])
# Out:
# ['Car / Jeep / Van', 'Car / Jeep / Van', 'Car / Jeep / Van', 'Car / Jeep / Van', 'Car / Jeep / Van', ..., 'Car / Jeep / Van', 'Car / Jeep / Van', 'Car / Jeep / Van', 'Car / Jeep / Van', 'Car / Jeep / Van']
# Length: 1012
# Categories (5, object): ['Bus 2-axle', 'Car / Jeep / Van', 'Light Commercial vehicle 2-axle', 'Mini-Bus', 'Tata Ace and Similar mini Light Commercial Ve...]

# %%
pd.Categorical(df["Pass Id"])
# Out:
# [14540747, 14104436, 14226402, 14042146, 14241813, ..., 14289576, 13978900, 14586345, 13997053, 13987106]
# Length: 1012
# Categories (1012, int64): [13961358, 13967396, 13973535, 13975770, ..., 14594286, 14601791, 14603969, 14621492]

# %%
df["Pass Id"].unique()
# Out:
# array([14540747, 14104436, 14226402, ..., 14586345, 13997053, 13987106])

# %%
df.head(2)
# Out:
#    Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 0        1  34161FA82033E6EE04FFF900          MP10CB0412                VC4
# 1        2  34161FA82033E6EE04FFF900          MP10CB0412                VC4
#
#   Vehicle Class Desc         Plaza Name   Pass Id            Pass Scheme  \
# 0   Car / Jeep / Van  Kurana Toll Plaza  14540747  Monthly Pass Non Comm
# 1   Car / Jeep / Van  Kurana Toll Plaza  14104436  Monthly Pass Non Comm
#
#   Pass Type              Pass Name  ... Stlmnt Amt (Rs.) Stlmnt Status  \
# 0        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 1        MP  Monthly Pass Non Comm  ...              NaN           NaN
#
#    Current Status    Issued By NPCI Plaza Id AutoRenewal  Old Pass Id  \
# 0         EXPIRED  139773.KUR2        320077          NO          NaN
# 1         EXPIRED  139773.KUR2        320077          NO          NaN
#
#    New Pass Id   A   B
# 0          NaN NaN NaN
# 1          NaN NaN NaN
#
# ...

# %%
# Condition statement
df["Vehicle Class Desc"]== "Bus 2-axle"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1007    False
# 1008    False
# 1009    False
# 1010    False
# 1011    False
# Name: Vehicle Class Desc, Length: 1012, dtype: bool

# %%
df[df["Vehicle Class Desc"]== "Bus 2-axle"]
# Out:
#      Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 882      883  34161FA8203288AC0F038E40          UP13AT4242                VC7
# 883      884  34161FA8203288AC0F038D40          UP15AT7202                VC7
# 884      885  34161FA8203288AC0F038D20          UP13AT5072                VC7
#
#     Vehicle Class Desc         Plaza Name   Pass Id        Pass Scheme  \
# 882         Bus 2-axle  Kurana Toll Plaza  14361148  Monthly Pass Comm
# 883         Bus 2-axle  Kurana Toll Plaza  14181866  Monthly Pass Comm
# 884         Bus 2-axle  Kurana Toll Plaza  14373461  Monthly Pass Comm
#
#     Pass Type          Pass Name  ... Stlmnt Amt (Rs.) Stlmnt Status  \
# 882        MP  Monthly Pass Comm  ...              NaN           NaN
# 883        MP  Monthly Pass Comm  ...              NaN           NaN
# 884        MP  Monthly Pass Comm  ...              NaN           NaN
#
#      Current Status    Issued By NPCI Plaza Id AutoRenewal  Old Pass Id  \
# ...

# %%
len(df[df["Vehicle Class Desc"]== "Bus 2-axle"])
# Out:
# 3

# %%
len(df)-len(df[df["Vehicle Class Desc"]== "Bus 2-axle"])
# Out:
# 1009

# %%
df.describe()
# Out:
#            Sr. No.       Pass Id  Trips Allowed  Trips Taken  Renewal Dt  \
# count  1012.000000  1.012000e+03    1012.000000  1012.000000         0.0
# mean    506.500000  1.415864e+07    9772.886364    19.414032         NaN
# std     292.283538  1.986372e+05    1483.459386    16.548568         NaN
# min       1.000000  1.396136e+07      50.000000     0.000000         NaN
# 25%     253.750000  1.400765e+07    9999.000000     7.000000         NaN
# 50%     506.500000  1.408078e+07    9999.000000    14.000000         NaN
# 75%     759.250000  1.422481e+07    9999.000000    30.000000         NaN
# max    1012.000000  1.462149e+07    9999.000000   105.000000         NaN
#
#        Issuance Fees (Rs.)  Payment Mode  Stlmnt Amt (Rs.)  NPCI Plaza Id  \
# count          1012.000000           0.0              97.0         1012.0
# mean            429.041502           NaN             315.0       320077.0
# std             841.516647           NaN               0.0            0.0
# ...

# %%
df.columns
# Out:
# Index(['Sr. No.', 'Tag ID', 'Chassis/ Vehicle No', 'NPCI Vehicle Class',
#        'Vehicle Class Desc', 'Plaza Name', 'Pass Id', 'Pass Scheme',
#        'Pass Type', 'Pass Name', 'Start Effective Date', 'End Effective Date',
#        'Trips Allowed', 'Trips Taken', 'Channel', 'Issuance Date',
#        'Renewal Dt', 'Issuance Fees (Rs.)', 'Payment Mode', 'Payment status',
#        'Stlmnt Dt', 'Stlmnt Amt (Rs.)', 'Stlmnt Status', 'Current Status',
#        'Issued By', 'NPCI Plaza Id', 'AutoRenewal', 'Old Pass Id',
#        'New Pass Id', 'A', 'B'],
#       dtype='object')

# %%
df[df["Issuance Fees (Rs.)"]>315]
# Out:
#      Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 5          6  34161FA820328EE8257B0640          UP37AT5373                VC4
# 13        14  34161FA820328EE824032D20   MA3JMTB1SPA826362                VC4
# 149      150  34161FA820328EE80CCA1A60           UP37T6482               VC20
# 161      162  34161FA820328EE809A1C880          UP13AT3049               VC20
# 217      218  34161FA820328E402A0CEFC0          UP37AT7854               VC20
# 231      232  34161FA820328E4029E91000          UP13CT3808               VC20
# 239      240  34161FA820328E4029B1D100          UP15DT4089                VC4
# 319      320  34161FA820328E4027ACF180          DL8CNB3216                VC4
# 466      467  34161FA820328E4012DA47C0          UP15CB2574                VC4
# 528      529  34161FA820328E4003EC8740          UP37AT3146               VC20
# 572      573  34161FA820328AA20E547DE0          UP16AC0722                VC4
# ...

# %%
df[(df["Issuance Fees (Rs.)"]>315) & (df["Trips Taken"]>19)]
# Out:
#      Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 5          6  34161FA820328EE8257B0640          UP37AT5373                VC4
# 13        14  34161FA820328EE824032D20   MA3JMTB1SPA826362                VC4
# 149      150  34161FA820328EE80CCA1A60           UP37T6482               VC20
# 217      218  34161FA820328E402A0CEFC0          UP37AT7854               VC20
# 231      232  34161FA820328E4029E91000          UP13CT3808               VC20
# 239      240  34161FA820328E4029B1D100          UP15DT4089                VC4
# 319      320  34161FA820328E4027ACF180          DL8CNB3216                VC4
# 466      467  34161FA820328E4012DA47C0          UP15CB2574                VC4
# 528      529  34161FA820328E4003EC8740          UP37AT3146               VC20
# 572      573  34161FA820328AA20E547DE0          UP16AC0722                VC4
# 751      752  34161FA8203289722C6922E0          UP15FT5694                VC9
# ...

# %%
df["Issuance Fees (Rs.)"]
# Out:
# 0       315
# 1       315
# 2       315
# 3       315
# 4       315
#        ...
# 1007    315
# 1008    315
# 1009    315
# 1010    315
# 1011    315
# Name: Issuance Fees (Rs.), Length: 1012, dtype: int64

# %%
df["Issuance Fees (Rs.)"]==max(df["Issuance Fees (Rs.)"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1007    False
# 1008    False
# 1009    False
# 1010    False
# 1011    False
# Name: Issuance Fees (Rs.), Length: 1012, dtype: bool

# %%
df[df["Issuance Fees (Rs.)"]==max(df["Issuance Fees (Rs.)"])]
# Out:
#      Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 882      883  34161FA8203288AC0F038E40          UP13AT4242                VC7
# 883      884  34161FA8203288AC0F038D40          UP15AT7202                VC7
# 884      885  34161FA8203288AC0F038D20          UP13AT5072                VC7
#
#     Vehicle Class Desc         Plaza Name   Pass Id        Pass Scheme  \
# 882         Bus 2-axle  Kurana Toll Plaza  14361148  Monthly Pass Comm
# 883         Bus 2-axle  Kurana Toll Plaza  14181866  Monthly Pass Comm
# 884         Bus 2-axle  Kurana Toll Plaza  14373461  Monthly Pass Comm
#
#     Pass Type          Pass Name  ... Stlmnt Amt (Rs.) Stlmnt Status  \
# 882        MP  Monthly Pass Comm  ...              NaN           NaN
# 883        MP  Monthly Pass Comm  ...              NaN           NaN
# 884        MP  Monthly Pass Comm  ...              NaN           NaN
#
#      Current Status    Issued By NPCI Plaza Id AutoRenewal  Old Pass Id  \
# ...

# %%
df[df["Issuance Fees (Rs.)"]==max(df["Issuance Fees (Rs.)"])]["Vehicle Class Desc"]
# Out:
# 882    Bus 2-axle
# 883    Bus 2-axle
# 884    Bus 2-axle
# Name: Vehicle Class Desc, dtype: object

# %%
df[0:3]
# Out:
#    Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 0        1  34161FA82033E6EE04FFF900          MP10CB0412                VC4
# 1        2  34161FA82033E6EE04FFF900          MP10CB0412                VC4
# 2        3  34161FA82033E6EE0488C6C0          UP32EF9515                VC4
#
#   Vehicle Class Desc         Plaza Name   Pass Id            Pass Scheme  \
# 0   Car / Jeep / Van  Kurana Toll Plaza  14540747  Monthly Pass Non Comm
# 1   Car / Jeep / Van  Kurana Toll Plaza  14104436  Monthly Pass Non Comm
# 2   Car / Jeep / Van  Kurana Toll Plaza  14226402  Monthly Pass Non Comm
#
#   Pass Type              Pass Name  ... Stlmnt Amt (Rs.) Stlmnt Status  \
# 0        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 1        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 2        MP  Monthly Pass Non Comm  ...              NaN           NaN
#
#    Current Status    Issued By NPCI Plaza Id AutoRenewal  Old Pass Id  \
# ...

# %%
df.iloc[4:7] # iloc excluded 7 # iloc understand the numeric or internal built index in column
# Out:
#    Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 4        5  34161FA82033E6EE02109740           UP37H8899                VC4
# 5        6  34161FA820328EE8257B0640          UP37AT5373                VC4
# 6        7  34161FA820328EE8257303A0           UP37C7656                VC4
#
#   Vehicle Class Desc         Plaza Name   Pass Id            Pass Scheme  \
# 4   Car / Jeep / Van  Kurana Toll Plaza  14241813  Monthly Pass Non Comm
# 5   Car / Jeep / Van  Kurana Toll Plaza  14371151      Monthly Pass Comm
# 6   Car / Jeep / Van  Kurana Toll Plaza  14041110  Monthly Pass Non Comm
#
#   Pass Type              Pass Name  ... Stlmnt Amt (Rs.) Stlmnt Status  \
# 4        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 5        MP      Monthly Pass Comm  ...              NaN           NaN
# 6        MP  Monthly Pass Non Comm  ...              NaN           NaN
#
#    Current Status    Issued By NPCI Plaza Id AutoRenewal  Old Pass Id  \
# ...

# %%
df.loc[4:7] # iloc not excluded 7 # loc understand the name index in column
# Out:
#    Sr. No.                    Tag ID Chassis/ Vehicle No NPCI Vehicle Class  \
# 4        5  34161FA82033E6EE02109740           UP37H8899                VC4
# 5        6  34161FA820328EE8257B0640          UP37AT5373                VC4
# 6        7  34161FA820328EE8257303A0           UP37C7656                VC4
# 7        8  34161FA820328EE824CFC860          DL3CCP0337                VC4
#
#   Vehicle Class Desc         Plaza Name   Pass Id            Pass Scheme  \
# 4   Car / Jeep / Van  Kurana Toll Plaza  14241813  Monthly Pass Non Comm
# 5   Car / Jeep / Van  Kurana Toll Plaza  14371151      Monthly Pass Comm
# 6   Car / Jeep / Van  Kurana Toll Plaza  14041110  Monthly Pass Non Comm
# 7   Car / Jeep / Van  Kurana Toll Plaza  13990305  Monthly Pass Non Comm
#
#   Pass Type              Pass Name  ... Stlmnt Amt (Rs.) Stlmnt Status  \
# 4        MP  Monthly Pass Non Comm  ...              NaN           NaN
# 5        MP      Monthly Pass Comm  ...              NaN           NaN
# ...

# %%
df.iloc[4:7,["Chassis/ Vehicle No",	"NPCI Vehicle Class",	"Vehicle Class Desc"]]
# iloc understand the numeric or internal built index in column
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.iloc[4:7,["Chassis/ Vehicle No",	"NPCI Vehicle Class",	"Vehicle Class Desc"]]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
# for remove error
df.iloc[4:7,[3,4,5]]
# Out:
#   NPCI Vehicle Class Vehicle Class Desc         Plaza Name
# 4                VC4   Car / Jeep / Van  Kurana Toll Plaza
# 5                VC4   Car / Jeep / Van  Kurana Toll Plaza
# 6                VC4   Car / Jeep / Van  Kurana Toll Plaza

# %%
df.loc[4:7,["Chassis/ Vehicle No",	"NPCI Vehicle Class",	"Vehicle Class Desc"]]
# loc understand the name index in column
# Out:
#   Chassis/ Vehicle No NPCI Vehicle Class Vehicle Class Desc
# 4           UP37H8899                VC4   Car / Jeep / Van
# 5          UP37AT5373                VC4   Car / Jeep / Van
# 6           UP37C7656                VC4   Car / Jeep / Van
# 7          DL3CCP0337                VC4   Car / Jeep / Van
