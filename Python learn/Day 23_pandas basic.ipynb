# %%
import pandas as pd

# %%
df=pd.read_csv("plazaPassList_01042023_111049.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Sr. No.', 'Tag ID', 'Chassis/ Vehicle No', 'NPCI Vehicle Class',
#        'Vehicle Class Desc', 'Plaza Name', 'Pass Id', 'Pass Scheme',
#        'Pass Type', 'Pass Name', 'Start Effective Date', 'End Effective Date',
#        'Trips Allowed', 'Trips Taken', 'Channel', 'Issuance Date',
#        'Renewal Dt', 'Issuance Fees (Rs.)', 'Payment Mode', 'Payment status',
#        'Stlmnt Dt', 'Stlmnt Amt (Rs.)', 'Stlmnt Status', 'Current Status',
#        'Issued By', 'NPCI Plaza Id', 'AutoRenewal', 'Old Pass Id',
#        'New Pass Id'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Sr. No.',
#  'Tag ID',
#  'Chassis/ Vehicle No',
#  'NPCI Vehicle Class',
#  'Vehicle Class Desc',
#  'Plaza Name',
#  'Pass Id',
#  'Pass Scheme',
#  'Pass Type',
#  'Pass Name',
#  'Start Effective Date',
#  'End Effective Date',
#  'Trips Allowed',
#  'Trips Taken',
#  'Channel',
#  'Issuance Date',
#  'Renewal Dt',
#  'Issuance Fees (Rs.)',
#  'Payment Mode',
#  'Payment status',
#  'Stlmnt Dt',
#  'Stlmnt Amt (Rs.)',
#  'Stlmnt Status',
#  'Current Status',
#  'Issued By',
#  'NPCI Plaza Id',
#  'AutoRenewal',
#  'Old Pass Id',
#  'New Pass Id']

# %%
df.head() # by default it give first 5 records
# Out:
#                                       Sr. No. Tag ID Chassis/ Vehicle No  \
# 1 34161FA82033E6EE04FFF900         MP10CB0412    VC4    Car / Jeep / Van
# 2 34161FA82033E6EE04FFF900         MP10CB0412    VC4    Car / Jeep / Van
# 3 34161FA82033E6EE0488C6C0         UP32EF9515    VC4    Car / Jeep / Van
# 4 34161FA82033E6EE04738A60  MA3EADE1S00444637    VC4    Car / Jeep / Van
# 5 34161FA82033E6EE02109740          UP37H8899    VC4    Car / Jeep / Van
#
#                            NPCI Vehicle Class  Vehicle Class Desc  \
# 1 34161FA82033E6EE04FFF900  Kurana Toll Plaza            14540747
# 2 34161FA82033E6EE04FFF900  Kurana Toll Plaza            14104436
# 3 34161FA82033E6EE0488C6C0  Kurana Toll Plaza            14226402
# 4 34161FA82033E6EE04738A60  Kurana Toll Plaza            14042146
# 5 34161FA82033E6EE02109740  Kurana Toll Plaza            14241813
#
#                                        Plaza Name Pass Id  \
# 1 34161FA82033E6EE04FFF900  Monthly Pass Non Comm      MP
# ...

# %%
df.tail() # by default it give last 5 records
# Out:
#                                   Sr. No. Tag ID Chassis/ Vehicle No  \
# 1008 34161FA82026C81C02D645C0  UP13AB1115    VC4    Car / Jeep / Van
# 1009 34161FA82026C81C028F52C0   UP37E9859    VC4    Car / Jeep / Van
# 1010 34161FA82026C81C020878C0  UP13AR3555    VC4    Car / Jeep / Van
# 1011 34161FA82026C81C020878C0  UP13AR3555    VC4    Car / Jeep / Van
# 1012 34161FA82026C81C0203A620  UP32KA3357    VC4    Car / Jeep / Van
#
#                               NPCI Vehicle Class  Vehicle Class Desc  \
# 1008 34161FA82026C81C02D645C0  Kurana Toll Plaza            14289576
# 1009 34161FA82026C81C028F52C0  Kurana Toll Plaza            13978900
# 1010 34161FA82026C81C020878C0  Kurana Toll Plaza            14586345
# 1011 34161FA82026C81C020878C0  Kurana Toll Plaza            13997053
# 1012 34161FA82026C81C0203A620  Kurana Toll Plaza            13987106
#
#                                           Plaza Name Pass Id  \
# 1008 34161FA82026C81C02D645C0  Monthly Pass Non Comm      MP
# ...

# %%
df.dtypes
# Out:
# Sr. No.                  object
# Tag ID                   object
# Chassis/ Vehicle No      object
# NPCI Vehicle Class       object
# Vehicle Class Desc        int64
# Plaza Name               object
# Pass Id                  object
# Pass Scheme              object
# Pass Type                object
# Pass Name                object
# Start Effective Date      int64
# End Effective Date        int64
# Trips Allowed            object
# Trips Taken              object
# Channel                 float64
# Issuance Date             int64
# Renewal Dt              float64
# Issuance Fees (Rs.)      object
# Payment Mode             object
# Payment status          float64
# Stlmnt Dt                object
# Stlmnt Amt (Rs.)         object
# Stlmnt Status            object
# Current Status            int64
# Issued By                object
# NPCI Plaza Id           float64
# AutoRenewal             float64
# Old Pass Id             float64
# New Pass Id             float64
# ...

# %%
df["Tag ID"]
# Out:
# 1     34161FA82033E6EE04FFF900    VC4
# 2     34161FA82033E6EE04FFF900    VC4
# 3     34161FA82033E6EE0488C6C0    VC4
# 4     34161FA82033E6EE04738A60    VC4
# 5     34161FA82033E6EE02109740    VC4
#                                  ...
# 1008  34161FA82026C81C02D645C0    VC4
# 1009  34161FA82026C81C028F52C0    VC4
# 1010  34161FA82026C81C020878C0    VC4
# 1011  34161FA82026C81C020878C0    VC4
# 1012  34161FA82026C81C0203A620    VC4
# Name: Tag ID, Length: 1012, dtype: object

# %%
type(df["Tag ID"])
# Out:
# pandas.core.series.Series

# %%
df[["Tag ID"]]
# Out:
#                               Tag ID
# 1    34161FA82033E6EE04FFF900    VC4
# 2    34161FA82033E6EE04FFF900    VC4
# 3    34161FA82033E6EE0488C6C0    VC4
# 4    34161FA82033E6EE04738A60    VC4
# 5    34161FA82033E6EE02109740    VC4
# ...                              ...
# 1008 34161FA82026C81C02D645C0    VC4
# 1009 34161FA82026C81C028F52C0    VC4
# 1010 34161FA82026C81C020878C0    VC4
# 1011 34161FA82026C81C020878C0    VC4
# 1012 34161FA82026C81C0203A620    VC4
#
# [1012 rows x 1 columns]

# %%
type(df[["Tag ID"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df["Tag ID","Pass Type"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Tag ID', 'Pass Type')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[["Tag ID","Pass Type"]]
# Out:
#                               Tag ID            Pass Type
# 1    34161FA82033E6EE04FFF900    VC4  01/03/2023 00:00:00
# 2    34161FA82033E6EE04FFF900    VC4  04/02/2023 00:00:00
# 3    34161FA82033E6EE0488C6C0    VC4  10/02/2023 00:00:00
# 4    34161FA82033E6EE04738A60    VC4  02/02/2023 00:00:00
# 5    34161FA82033E6EE02109740    VC4  11/02/2023 00:00:00
# ...                              ...                  ...
# 1008 34161FA82026C81C02D645C0    VC4  14/02/2023 00:00:00
# 1009 34161FA82026C81C028F52C0    VC4  01/02/2023 00:00:00
# 1010 34161FA82026C81C020878C0    VC4  01/03/2023 00:00:00
# 1011 34161FA82026C81C020878C0    VC4  01/02/2023 00:00:00
# 1012 34161FA82026C81C0203A620    VC4  01/02/2023 00:00:00
#
# [1012 rows x 2 columns]

# %%
# howto import excel datasheet

# %%
df1=pd.read_excel("ATMS_januray_23.xlsx")

# %%
df2=df1.head(3)

# %%
df2
# Out:
#    Unnamed: 0 Unnamed: 1      Unnamed: 2           Unnamed: 3  \
# 0         NaN    Sr. No.  Equipment Name  2023-01-01 00:00:00
# 1         NaN          1             ECB             10:15:00
# 2         NaN          2             PTZ             10:15:00
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 0  2023-01-02 00:00:00  2023-01-03 00:00:00  2023-01-04 00:00:00
# 1             11:15:00             10:15:00             11:30:00
# 2             11:15:00             10:15:00             11:30:00
#
#             Unnamed: 7           Unnamed: 8           Unnamed: 9  ...  \
# 0  2023-01-05 00:00:00  2023-01-06 00:00:00  2023-01-07 00:00:00  ...
# 1             12:20:00             14:15 PM             09:45:00  ...
# 2             12:20:00             14:15 PM             09:45:00  ...
#
#            Unnamed: 24          Unnamed: 25          Unnamed: 26  \
# 0  2023-01-22 00:00:00  2023-01-23 00:00:00  2023-01-24 00:00:00
# ...

# %%
df3=df2.to_excel("data_test.xlsx",index=False) # Index basically for remove index data in column from output

# %%
df4=pd.read_excel("data_test.xlsx")

# %%
df4
# Out:
#    Unnamed: 0 Unnamed: 1      Unnamed: 2           Unnamed: 3  \
# 0         NaN    Sr. No.  Equipment Name  2023-01-01 00:00:00
# 1         NaN          1             ECB             10:15:00
# 2         NaN          2             PTZ             10:15:00
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 0  2023-01-02 00:00:00  2023-01-03 00:00:00  2023-01-04 00:00:00
# 1             11:15:00             10:15:00             11:30:00
# 2             11:15:00             10:15:00             11:30:00
#
#             Unnamed: 7           Unnamed: 8           Unnamed: 9  ...  \
# 0  2023-01-05 00:00:00  2023-01-06 00:00:00  2023-01-07 00:00:00  ...
# 1             12:20:00             14:15 PM             09:45:00  ...
# 2             12:20:00             14:15 PM             09:45:00  ...
#
#            Unnamed: 24          Unnamed: 25          Unnamed: 26  \
# 0  2023-01-22 00:00:00  2023-01-23 00:00:00  2023-01-24 00:00:00
# ...

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 63.3 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml
import pandas as pd
url_data=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2022.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 13

# %%
url_data[3]
# Out:
#          Western Conference                   W                   L  \
# 0        Northwest Division  Northwest Division  Northwest Division
# 1                Utah Jazz*                  49                  33
# 2           Denver Nuggets*                  48                  34
# 3   Minnesota Timberwolves*                  46                  36
# 4    Portland Trail Blazers                  27                  55
# 5     Oklahoma City Thunder                  24                  58
# 6          Pacific Division    Pacific Division    Pacific Division
# 7             Phoenix Suns*                  64                  18
# 8    Golden State Warriors*                  53                  29
# 9      Los Angeles Clippers                  42                  40
# 10       Los Angeles Lakers                  33                  49
# 11         Sacramento Kings                  30                  52
# 12       Southwest Division  Southwest Division  Southwest Division
# ...
