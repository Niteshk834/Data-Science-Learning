# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("IPL_Dataset_Miniproject.csv")

# %%
df
# Out:
#      POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1           KL Rahul   14    14   2   670  132*  55.83  518  129.34
# 1      2     Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 2      3       David Warner   16    16   2   548   85*  39.14  407  134.64
# 3      4       Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27
# 4      5       Ishan Kishan   14    13   4   516    99  57.33  354  145.76
# ..   ...                ...  ...   ...  ..   ...   ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0    0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0    0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0    0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0    0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0    0*   0.00    1    0.00
#
#      100  50  4s  6s
# 0      1   5  58  23
# 1      2   4  67  12
# ...

# %%
df.shape
# Out:
# (133, 14)

# %%
df.size
# Out:
# 1862

# %%
df.columns
# Out:
# Index(['POS', 'Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Avg', 'BF', 'SR',
#        '100', '50', '4s', '6s'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Insights

# %% [markdown]
# Look like data is cleaned and we can proceed further for analysis.

# %% [markdown]
# ## Q1. What is the maximum number of matches played by an individual player in a season?

# %%
df["Mat"].max()
# Out:
# 17

# %%
df1=df[df["Mat"]==17]

# %%
df1
# Out:
#     POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 1     2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 3     4    Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27    0
# 19   20  Marcus Stoinis   17    17   3   352    65  25.14  237  148.52    0
# 67   68   Kagiso Rabada   17     8   4    56   15*  14.00   49  114.28    0
#
#     50  4s  6s
# 1    4  67  12
# 3    3  40  16
# 19   3  31  16
# 67   0   4   2

# %%
df1[["Player","Mat"]]
# Out:
#             Player  Mat
# 1   Shikhar Dhawan   17
# 3     Shreyas Iyer   17
# 19  Marcus Stoinis   17
# 67   Kagiso Rabada   17

# %% [markdown]
# ### Insights
#
# Shikhar Dhawan, Shreyas Iyer,Marcus Stoinis and Kagiso Rabada played the maximum no. of match i.e. 17

# %% [markdown]
# ## 2. What is the highest average of a player in a season?

# %%
df["Avg"].max()
# Out:
# 101.0

# %%
df[df["Avg"]==df["Avg"].max()][["Avg","Player"]]
# Out:
#       Avg        Player
# 57  101.0  Deepak Hooda

# %% [markdown]
# ### Insights
#
# Highest average of a player in a season is 101.0 and the player name is Deepak Hooda

# %% [markdown]
# ## 3. What is the average number of matches played by the players in a season?

# %%
df.head()
# Out:
#    POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0    1        KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1    2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2    3    David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 3    4    Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27    0
# 4    5    Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
#
#    50  4s  6s
# 0   5  58  23
# 1   4  67  12
# 2   4  52  14
# 3   3  40  16
# 4   4  36  30

# %%
df["Mat"].mean()
# Out:
# 9.631578947368421

# %% [markdown]
# ### Insights
# Average No. of matches played by the players in a season is 9

# %%
# 2nd way

# %%
# create new column
df["Avg_Match"]=(df["Mat"]/df["Mat"].count()).round(2)

# %%
df.head(1)
# Out:
#    POS    Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  4s  \
# 0    1  KL Rahul   14    14   2   670  132*  55.83  518  129.34    1   5  58
#
#    6s  Avg_Match
# 0  23       0.11

# %%
plt.figure(figsize=(25,30))
sns.barplot(x="Avg_Match",y="Player",data=df,color="b",hue="Avg_Match")
plt.show()

# %% [markdown]
# ## 4. Please check the correlation between all the features.

# %%
df
# Out:
#      POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1           KL Rahul   14    14   2   670  132*  55.83  518  129.34
# 1      2     Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 2      3       David Warner   16    16   2   548   85*  39.14  407  134.64
# 3      4       Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27
# 4      5       Ishan Kishan   14    13   4   516    99  57.33  354  145.76
# ..   ...                ...  ...   ...  ..   ...   ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0    0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0    0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0    0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0    0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0    0*   0.00    1    0.00
#
#      100  50  4s  6s
# 0      1   5  58  23
# 1      2   4  67  12
# ...

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df.corr()
# Out:
#            POS       Mat      Inns        NO      Runs       Avg        BF  \
# POS   1.000000 -0.556695 -0.916174 -0.386247 -0.896664 -0.746510 -0.891969
# Mat  -0.556695  1.000000  0.728358  0.555261  0.565237  0.306128  0.555102
# Inns -0.916174  0.728358  1.000000  0.464356  0.895914  0.585148  0.889753
# NO   -0.386247  0.555261  0.464356  1.000000  0.308747  0.429888  0.271021
# Runs -0.896664  0.565237  0.895914  0.308747  1.000000  0.687475  0.989948
# Avg  -0.746510  0.306128  0.585148  0.429888  0.687475  1.000000  0.664173
# BF   -0.891969  0.555102  0.889753  0.271021  0.989948  0.664173  1.000000
# SR   -0.730489  0.371328  0.581468  0.415060  0.517678  0.591306  0.474226
# 100  -0.248353  0.128405  0.224328  0.019726  0.382577  0.233726  0.358550
# 50   -0.769577  0.455437  0.755027  0.174184  0.912264  0.638326  0.900547
# 4s   -0.846965  0.522628  0.846749  0.204779  0.959576  0.623643  0.955994
# ...

# %%
sns.pairplot(df)

# %%
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## 5. Check the list of players who has an average greater than 50 as well strike rate above 120.

# %%
df.head(2)
# Out:
#    POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0    1        KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1    2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
#
#    50  4s  6s
# 0   5  58  23
# 1   4  67  12

# %%
df2=df[(df["Avg"]>50) & (df["SR"]>120)]

# %%
df2
# Out:
#     POS           Player  Mat  Inns  NO  Runs    HS     Avg   BF      SR  100  \
# 0     1         KL Rahul   14    14   2   670  132*   55.83  518  129.34    1
# 4     5     Ishan Kishan   14    13   4   516    99   57.33  354  145.76    0
# 31   32   Kieron Pollard   16    12   7   268   60*   53.60  140  191.42    0
# 36   37  Wriddhiman Saha    4     4   1   214    87   71.33  153  139.86    0
# 37   38  Ruturaj Gaikwad    6     6   2   204    72   51.00  169  120.71    0
# 57   58     Deepak Hooda    7     5   4   101   62*  101.00   71  142.25    0
# 60   61       Tom Curran    5     4   3    83   54*   83.00   62  133.87    0
#
#     50  4s  6s
# 0    5  58  23
# 4    4  36  30
# 31   1  15  22
# 36   2  24   5
# 37   3  16   6
# 57   1   5   5
# 60   1   5   3

# %%
# List of players whoose have Average>100 and Strike rate>120
list(df2["Player"])
# Out:
# ['KL Rahul',
#  'Ishan Kishan',
#  'Kieron Pollard',
#  'Wriddhiman Saha',
#  'Ruturaj Gaikwad',
#  'Deepak Hooda',
#  'Tom Curran']

# %% [markdown]
# ## 6. Please check the list of players who has an average greater than 40 and balls faced above 100.

# %%
df.head(2)
# Out:
#    POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0    1        KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1    2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
#
#    50  4s  6s
# 0   5  58  23
# 1   4  67  12

# %%
df[(df["Avg"]>40) & (df["BF"]>100)]
# Out:
#     POS           Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1         KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2   Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 4     5     Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 8     9      Virat Kohli   15    15   4   466   90*  42.36  384  121.35    0
# 9    10   AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 10   11   Faf du Plessis   13    13   2   449   87*  40.81  319  140.75    0
# 14   15      Eoin Morgan   14    14   4   418   68*  41.80  302  138.41    0
# 24   25  Kane Williamson   12    11   4   317    67  45.28  237  133.75    0
# 27   28      Chris Gayle    7     7   0   288    99  41.14  210  137.14    0
# 28   29       Ben Stokes    8     8   1   285  107*  40.71  200  142.50    1
# 31   32   Kieron Pollard   16    12   7   268   60*  53.60  140  191.42    0
# ...

# %%
list(df[(df["Avg"]>40) & (df["BF"]>100)]["Player"])
# Out:
# ['KL Rahul',
#  'Shikhar Dhawan',
#  'Ishan Kishan',
#  'Virat Kohli',
#  'AB de Villiers',
#  'Faf du Plessis',
#  'Eoin Morgan',
#  'Kane Williamson',
#  'Chris Gayle',
#  'Ben Stokes',
#  'Kieron Pollard',
#  'Rahul Tewatia',
#  'Ravindra Jadeja',
#  'Wriddhiman Saha',
#  'Ruturaj Gaikwad']

# %% [markdown]
# ## 7. Please check the list of players who scored more than 300 runs with an average greater than 45 & strike rate above 130.

# %%
df.head(1)
# Out:
#    POS    Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  4s  \
# 0    1  KL Rahul   14    14   2   670  132*  55.83  518  129.34    1   5  58
#
#    6s
# 0  23

# %%
df[(df["Runs"]>300) & (df["Avg"]>45) & (df["SR"]>130)]
# Out:
#     POS           Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  100  \
# 4     5     Ishan Kishan   14    13   4   516   99  57.33  354  145.76    0
# 9    10   AB de Villiers   15    14   4   454  73*  45.40  286  158.74    0
# 24   25  Kane Williamson   12    11   4   317   67  45.28  237  133.75    0
#
#     50  4s  6s
# 4    4  36  30
# 9    5  33  23
# 24   3  26  10

# %%
# list of players who scored more than 300 runs with an average greater than 45 & strike rate above 130.
list(df[(df["Runs"]>300) & (df["Avg"]>45) & (df["SR"]>130)]["Player"])
# Out:
# ['Ishan Kishan', 'AB de Villiers', 'Kane Williamson']

# %% [markdown]
# ## 8. Players who scroed alteast one century in this season.

# %%
df.head(1)
# Out:
#    POS    Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  4s  \
# 0    1  KL Rahul   14    14   2   670  132*  55.83  518  129.34    1   5  58
#
#    6s
# 0  23

# %%
df[df["100"]>=1]
# Out:
#     POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1        KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 13   14  Mayank Agarwal   11    11   0   424   106  38.54  271  156.45    1
# 28   29      Ben Stokes    8     8   1   285  107*  40.71  200  142.50    1
#
#     50  4s  6s
# 0    5  58  23
# 1    4  67  12
# 13   2  44  15
# 28   1  36   7

# %%
# Players who scroed alteast one century in this season.
list(df[df["100"]>=1]["Player"])
# Out:
# ['KL Rahul', 'Shikhar Dhawan', 'Mayank Agarwal', 'Ben Stokes']

# %% [markdown]
# ## 9. Players who scored atleast 4 half centuries in this season.

# %%
# Players who scored atleast 4 half centuries in this season.
list(df[df["50"]>=4]["Player"])
# Out:
# ['KL Rahul',
#  'Shikhar Dhawan',
#  'David Warner',
#  'Ishan Kishan',
#  'Quinton de Kock',
#  'Suryakumar Yadav',
#  'Devdutt Padikkal',
#  'AB de Villiers',
#  'Faf du Plessis']

# %% [markdown]
# ## 10. Check the list of players who hit more than 45 boundARIES and more than 10 sixes in this season.

# %%
df.head(1)
# Out:
#    POS    Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  4s  \
# 0    1  KL Rahul   14    14   2   670  132*  55.83  518  129.34    1   5  58
#
#    6s
# 0  23

# %%
# list of players who hit more than 45 boundARIES and more than 10 sixes in this season.
list(df[(df["4s"]>45) & (df["6s"]>10)]["Player"])
# Out:
# ['KL Rahul',
#  'Shikhar Dhawan',
#  'David Warner',
#  'Quinton de Kock',
#  'Suryakumar Yadav']

# %% [markdown]
# ## 11. Plot a histogram of number of matches played in a season by players.

# %%
df["Mat"].value_counts()
# Out:
# 14    22
# 15    10
# 7     10
# 3     10
# 16     9
# 5      9
# 12     8
# 13     7
# 2      7
# 10     6
# 9      6
# 8      6
# 1      6
# 6      5
# 11     5
# 17     4
# 4      3
# Name: Mat, dtype: int64

# %%
sns.histplot(df["Mat"])
plt.xlabel("No. of Match played")
plt.ylabel("How much player played the match ")
plt.show()

# %% [markdown]
# ## Insights

# %% [markdown]
# 1. 1 to 2 match played by 13 player
# 2. 3 to 4 match played by 13 player
# 3. 5 to 6 match played by 14 player
# 2. 7 to 8 match played by 16 player
# 2. 9 to 10 match played by 12 player
# 2. 11 to 12 match played by 13 player
# 2. 13 to 14 match played by 29 player
# 2. 15 to 16 match played by 19 player
# 2. 17 match which is maximum and played by 4 player

# %% [markdown]
# ## 12. Plot the histogram of balls faced by players.

# %%
df.head(1)
# Out:
#    POS    Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  4s  \
# 0    1  KL Rahul   14    14   2   670  132*  55.83  518  129.34    1   5  58
#
#    6s
# 0  23

# %%
df["BF"].value_counts()
# Out:
# 2      7
# 3      6
# 4      4
# 6      4
# 15     4
#       ..
# 241    1
# 157    1
# 200    1
# 210    1
# 105    1
# Name: BF, Length: 89, dtype: int64

# %%
sns.histplot(df["BF"],bins=5)
plt.xlabel("Ball Faced by player")

plt.ylabel("No. of player")
plt.show()

# %% [markdown]
# ## Insights

# %% [markdown]
# 1. 84 players who faced 0 to 100 balls
# 2. 20 players who faced 100 to 200 balls
# 3. 16 players who faced 200 to 300 balls
# 4. 10 players who faced 300 to 400 balls
# 5. 3 players who faced 400 to 500 balls
# 6. 1 players who faced greater than 500 balls

# %% [markdown]
# ## 13. Top 20 players with most runs in a season.

# %%
df.head(1)
# Out:
#    POS    Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  4s  \
# 0    1  KL Rahul   14    14   2   670  132*  55.83  518  129.34    1   5  58
#
#    6s
# 0  23

# %%
df3=df.sort_values(by="Runs",ascending=False)[0:20]

# %%
df3[["Player","Runs"]]
# Out:
#               Player  Runs
# 0           KL Rahul   670
# 1     Shikhar Dhawan   618
# 2       David Warner   548
# 3       Shreyas Iyer   519
# 4       Ishan Kishan   516
# 5    Quinton de Kock   503
# 6   Suryakumar Yadav   480
# 7   Devdutt Padikkal   473
# 8        Virat Kohli   466
# 9     AB de Villiers   454
# 10    Faf du Plessis   449
# 11      Shubman Gill   440
# 12     Manish Pandey   425
# 13    Mayank Agarwal   424
# 14       Eoin Morgan   418
# 15      Sanju Samson   375
# 16     Ambati Rayudu   359
# 17   Nicholas Pooran   353
# 18       Nitish Rana   352
# 19    Marcus Stoinis   352

# %%
# Top 20 player who hit more run than other players
list(df3["Player"])
# Out:
# ['KL Rahul',
#  'Shikhar Dhawan',
#  'David Warner',
#  'Shreyas Iyer',
#  'Ishan Kishan',
#  'Quinton de Kock',
#  'Suryakumar Yadav',
#  'Devdutt Padikkal',
#  'Virat Kohli',
#  'AB de Villiers',
#  'Faf du Plessis',
#  'Shubman Gill',
#  'Manish Pandey',
#  'Mayank Agarwal',
#  'Eoin Morgan',
#  'Sanju Samson',
#  'Ambati Rayudu',
#  'Nicholas Pooran',
#  'Nitish Rana',
#  'Marcus Stoinis']

# %%
plt.figure(figsize=(20,15))
plt.bar(df3["Player"],df3["Runs"],color="r")
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# ## 14. Bar chart for top 20 players with best strike rate in a season.

# %%
df4=df.sort_values(by="SR",ascending=False)[0:20]

# %%
df4[["Player","SR"]]
# Out:
#                   Player      SR
# 31        Kieron Pollard  191.42
# 50          Jofra Archer  179.36
# 29         Hardik Pandya  178.98
# 83      Tushar Deshpande  175.00
# 33       Ravindra Jadeja  171.85
# 53           Abdul Samad  170.76
# 17       Nicholas Pooran  169.71
# 81   Nathan Coulter-Nile  166.66
# 110       Jasprit Bumrah  166.66
# 74          Chris Morris  161.90
# 15          Sanju Samson  158.89
# 9         AB de Villiers  158.74
# 13        Mayank Agarwal  156.45
# 69    Krishnappa Gowtham  155.55
# 113      Dhawal Kulkarni  150.00
# 19        Marcus Stoinis  148.52
# 68       Lockie Ferguson  148.27
# 41       Shimron Hetmyer  148.00
# 4           Ishan Kishan  145.76
# 6       Suryakumar Yadav  145.01

# %%
plt.figure(figsize=(20,15))
sns.barplot(x="Player",y="SR",data=df4,color="r",hue=df4["SR"])
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# ## 15. Top 30 players with highest number of sixes.

# %%
df.head(1)
# Out:
#    POS    Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  4s  \
# 0    1  KL Rahul   14    14   2   670  132*  55.83  518  129.34    1   5  58
#
#    6s
# 0  23

# %%
df.sort_values(by="6s",ascending=False)[0:30]
# Out:
#     POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 4     5      Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 15   16      Sanju Samson   14    14   1   375    85  28.84  236  158.89    0
# 29   30     Hardik Pandya   14    13   5   281   60*  35.12  157  178.98    0
# 17   18   Nicholas Pooran   14    14   4   353    77  35.30  208  169.71    0
# 14   15       Eoin Morgan   14    14   4   418   68*  41.80  302  138.41    0
# 9    10    AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 27   28       Chris Gayle    7     7   0   288    99  41.14  210  137.14    0
# 0     1          KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 31   32    Kieron Pollard   16    12   7   268   60*  53.60  140  191.42    0
# 5     6   Quinton de Kock   16    16   2   503   78*  35.92  358  140.50    0
# 22   23      Rohit Sharma   12    12   0   332    80  27.66  260  127.69    0
# ...

# %%
# list of top 30 player with highest number of sixes is:
df5=df.sort_values(by="6s",ascending=False)[0:30]

# %%
df5[["Player","6s"]]
# Out:
#               Player  6s
# 4       Ishan Kishan  30
# 15      Sanju Samson  26
# 29     Hardik Pandya  25
# 17   Nicholas Pooran  25
# 14       Eoin Morgan  24
# 9     AB de Villiers  23
# 27       Chris Gayle  23
# 0           KL Rahul  23
# 31    Kieron Pollard  22
# 5    Quinton de Kock  22
# 22      Rohit Sharma  19
# 12     Manish Pandey  18
# 32     Rahul Tewatia  17
# 3       Shreyas Iyer  16
# 23       Jos Buttler  16
# 19    Marcus Stoinis  16
# 13    Mayank Agarwal  15
# 10    Faf du Plessis  14
# 2       David Warner  14
# 20    Jonny Bairstow  13
# 26      Shane Watson  13
# 40        Sam Curran  12
# 18       Nitish Rana  12
# 16     Ambati Rayudu  12
# 41   Shimron Hetmyer  12
# 1     Shikhar Dhawan  12
# 8        Virat Kohli  11
# 33   Ravindra Jadeja  11
# 6   Suryakumar Yadav  11
# 24   Kane Williamson  10

# %%
list(df5["Player"])
# Out:
# ['Ishan Kishan',
#  'Sanju Samson',
#  'Hardik Pandya',
#  'Nicholas Pooran',
#  'Eoin Morgan',
#  'AB de Villiers',
#  'Chris Gayle',
#  'KL Rahul',
#  'Kieron Pollard',
#  'Quinton de Kock',
#  'Rohit Sharma',
#  'Manish Pandey',
#  'Rahul Tewatia',
#  'Shreyas Iyer',
#  'Jos Buttler',
#  'Marcus Stoinis',
#  'Mayank Agarwal',
#  'Faf du Plessis',
#  'David Warner',
#  'Jonny Bairstow',
#  'Shane Watson',
#  'Sam Curran',
#  'Nitish Rana',
#  'Ambati Rayudu',
#  'Shimron Hetmyer',
#  'Shikhar Dhawan',
#  'Virat Kohli',
#  'Ravindra Jadeja',
#  'Suryakumar Yadav',
#  'Kane Williamson']

# %% [markdown]
# ## 16. Scatter plot of runs scored by a player v/s balls faced in a season.

# %%
df.head(1)
# Out:
#    POS    Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  4s  \
# 0    1  KL Rahul   14    14   2   670  132*  55.83  518  129.34    1   5  58
#
#    6s
# 0  23

# %%
plt.figure(figsize=(25,40))
sns.scatterplot(y="Player",x="BF",data=df,s=300,hue="BF")
plt.tick_params(axis='both', which='major', labelsize=15)
plt.show()

# %% [markdown]
# ## 17. KDE plot for averages on a season

# %%
df.head(1)
# Out:
#    POS    Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  50  4s  \
# 0    1  KL Rahul   14    14   2   670  132*  55.83  518  129.34    1   5  58
#
#    6s
# 0  23

# %%
sns.kdeplot(df["Avg"])
plt.show()
