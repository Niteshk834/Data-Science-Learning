# %%
import pandas as pd

# %%
df=pd.read_csv("stud.csv")

# %%
df.head(3)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
df.shape
# Out:
# (1000, 8)

# %%
# check missing values
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# In above, there are no missing values

# %%
#check null value
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# No NaN value present above

# %%
# check duplicate data
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum() # No duplicate found
# Out:
# 0

# %%
# check datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# check unique value of each column
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
# check statistics of data set
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df["math_score"].min()
# Out:
# 0

# %%
# explore more info about the data
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# segregate numerical and catagorical feature

# %%
[feature for feature in df.columns if df[feature].dtype!="O"] # Here "o" is not zero. its o
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
[feature for feature in df.columns if df[feature].dtype=="O"]
# Out:
# ['gender',
#  'race_ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course']

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
df["total_score"]=(df["math_score"]+df["reading_score"]+df["writing_score"])

# %%
df["total_score"]
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Name: total_score, Length: 1000, dtype: int64

# %%
df["Average_score"]=df["total_score"]/3

# %%
df["Average_score"]
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: Average_score, Length: 1000, dtype: float64

# %%
df.head() # Now we got total and average score in new column
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  Average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# 3          148      49.333333
# 4          229      76.333333

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total_score', 'Average_score'],
#       dtype='object')

# %%
# Explore more visualization
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
fig,axis=plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x="Average_score",bins=30,kde=True,color="g")
plt.subplot(122)
sns.histplot(data=df,x="Average_score",bins=30,kde=True,hue="gender")# I want to see Average_score based on
                                                                     # gender
plt.show()

# %% [markdown]
# #### Insights
#
# female student tend to perform well than male student

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x="Average_score",kde=True,hue="lunch")
plt.subplot(142)
sns.histplot(data=df[df.gender=="female"],x="Average_score",kde=True,hue="lunch")
plt.subplot(143)
sns.histplot(data=df[df.gender=="male"],x="Average_score",kde=True,hue="lunch")
plt.show()
# Out:
# /tmp/ipykernel_84/2117306540.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# /tmp/ipykernel_84/2117306540.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# /tmp/ipykernel_84/2117306540.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)

# %% [markdown]
# ### Insights
#
# 1. standard lunch help student perform well in exams
#
# 2. standard lunch help student perform well in exam for both male and female

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x="Average_score",kde=True,hue="parental_level_of_education")
plt.subplot(142)
sns.histplot(data=df[df.gender=="male"],x="Average_score",kde=True,hue="parental_level_of_education")
plt.subplot(143)
sns.histplot(data=df[df.gender=="female"],x="Average_score",kde=True,hue="parental_level_of_education")
plt.show()
# Out:
# /tmp/ipykernel_84/2521581622.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# /tmp/ipykernel_84/2521581622.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# /tmp/ipykernel_84/2521581622.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)

# %% [markdown]
# ### Insight
#
# 1. In general parent not help student to perform well in exam
#
# 2. parents whose education is of associate degree and Master degree there male child perform well in exam
#
# 3. There is no effect of parent's education on girl performance.

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x="Average_score",kde=True,hue="race_ethnicity")
plt.subplot(142)
sns.histplot(data=df[df.gender=="female"],x="Average_score",kde=True,hue="race_ethnicity")
plt.subplot(143)
sns.histplot(data=df[df.gender=="male"],x="Average_score",kde=True,hue="race_ethnicity")
plt.show()
# Out:
# /tmp/ipykernel_84/738770565.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# /tmp/ipykernel_84/738770565.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# /tmp/ipykernel_84/738770565.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)

# %% [markdown]
# ### Insight
# 1. Group A and Group B tends to perform poorly in exam
#
# 2. Group A and Group B tends to perform poorly in exam irrespective of male and female

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x="Average_score",kde=True,hue="test_preparation_course")
plt.subplot(142)
sns.histplot(data=df[df.gender=="female"],x="Average_score",kde=True,hue="test_preparation_course")
plt.subplot(143)
sns.histplot(data=df[df.gender=="male"],x="Average_score",kde=True,hue="test_preparation_course")
plt.show()
# Out:
# /tmp/ipykernel_84/3500652062.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# /tmp/ipykernel_84/3500652062.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# /tmp/ipykernel_84/3500652062.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)

# %%
sns.pairplot(df) # We didn't execute becuase it's getting a problem to save the file

# The screenshot of output will look like this:

# %% [markdown]
# ![pairplot.JPG](attachment:f23c3cc4-2652-481f-b80f-22cc58c17a6c.JPG)

# %%
sns.heatmap(df.corr())
# Out:
# /tmp/ipykernel_84/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# /tmp/ipykernel_84/4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <AxesSubplot: >
